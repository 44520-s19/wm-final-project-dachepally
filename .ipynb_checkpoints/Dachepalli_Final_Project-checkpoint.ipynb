# %% [markdown]
# # NAME: SAI SRI DACHEPALLI

# %% [markdown]
# ## TOP 25 Instagram users by followers

# %% [markdown]
# ## Question:

# %% [markdown]
# ### Find Instagram accounts with highest number of followers, highest number of posts and compare whether top followed accounts have highest posts than the other accounts with less number of followers.

# %% [markdown]
# ##### To find solution, I am using "socialblade website". I web scraped top 25 Instagram accounts by followers and posts, and collected observations. I Cleaned the data collected and Visualized the observations.

# %%
###### Libraries imported
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
# website used for web scraping
url = "https://socialblade.com/instagram/"

# %%
# sending html requests to the site
html = requests.get(url)
results = html.text

# %% [markdown]
# ### Pickling data

# %%
import pickle
# pickling data
with open('data.pkl', 'wb') as f:
    pickle.dump(results, f)

# loading data from a pickle file
with open('data.pkl', 'rb') as f:
    new_results = pickle.load(f)
    print(type(new_results))
# Out:
# <class 'str'>

# %%
## Extracting the results from the new_results and storing it in soup
soup = BeautifulSoup(new_results)
body = soup.findAll("div",{"class": "table-body"})

# %%
def prepare_table_row(row):
    lst = [i.text for i in row if i !=u'\n']
    #return lst
    return dict(rank = int(lst[0]), grade = str(lst[1]), username = str(lst[2]),Name = str(lst[3]), posts = float(lst[4].replace(",","")), followers = float(lst[5].replace(",","")), following = float(lst[6].replace(",","")))

# %%
# printing the result of first row
print(prepare_table_row(body[0]))
# Out:
# {'rank': 1, 'grade': 'A++ ', 'username': 'therock', 'Name': 'therock', 'posts': 4279.0, 'followers': 145664920.0, 'following': 370.0}

# %%
# performing iterations to obtain all the results
data = []
for tr in body:
    datum = prepare_table_row(tr)
    for a in tr.find_all('a', href= True):
        datum['url'] = a['href']
    data.append(datum)

# %%
# storing the result in pandas data frame
df = pd.DataFrame(data)
df
# Out:
#                         Name    followers  following grade    posts  rank  \
# 0                    therock  145664920.0      370.0  A++    4279.0     1
# 1                  Leo Messi  123905769.0      228.0  A++     474.0     2
# 2                   3n310ta   113580705.0      993.0  A++    4430.0     3
# 3        National Geographic  112514923.0      131.0  A++   20489.0     4
# 4             Jennifer Lopez   95777045.0     1101.0  A++    2583.0     5
# 5                Miley Cyrus   94927303.0      780.0  A++     333.0     6
# 6                       nike   89453277.0       54.0  A++     733.0     7
# 7                 KATY PERRY   83335390.0      473.0  A++    1254.0     8
# 8                 Kevin Hart   76315848.0      554.0  A++    6371.0     9
# 9           Real Madrid C.F.   74246209.0       40.0  A++    2758.0    10
# 10                     Ellen   73987069.0      368.0  A++    7604.0    11
# 11              FC Barcelona   73020981.0       52.0  A++   11977.0    12
# 12         Victoria's Secret   67429383.0      573.0  A++    7761.0    13
# 13    9GAG: Go Fun The World   50387766.0       28.0  A++   20062.0    14
# 14  Ronaldo de Assis Moreira   46592552.0      316.0  A++    2365.0    15
# 15            MOSTHATEDCARDI   46562771.0     3096.0  A++     786.0    16
# 16                      NASA   44948240.0       85.0  A++    2652.0    17
# 17     UEFA Champions League   42805504.0      481.0  A++    9110.0    18
# 18     Priyanka Chopra Jonas   42635997.0      458.0  A++    2902.0    19
# 19           James Rodríguez   42080184.0      518.0  A++     860.0    20
# 20               Gareth Bale   40238795.0       64.0  A++     837.0    21
# 21    Nike Football (Soccer)   39127128.0      294.0  A++    1703.0    22
# 22      Marvel Entertainment   39013176.0      152.0  A++    3553.0    23
# 23        Marcelo Vieira Jr.   38964331.0     1294.0  A++    2065.0    24
# 24                   anitta    38851663.0     1781.0  A++    3789.0    25
#
#                                  url          username
# 0            /instagram/user/therock           therock
# 1           /instagram/user/leomessi          leomessi
# 2           /instagram/user/neymarjr          neymarjr
# 3             /instagram/user/natgeo            natgeo
# 4                /instagram/user/jlo               jlo
# 5         /instagram/user/mileycyrus        mileycyrus
# 6               /instagram/user/nike              nike
# 7          /instagram/user/katyperry         katyperry
# 8     /instagram/user/kevinhart4real    kevinhart4real
# 9         /instagram/user/realmadrid        realmadrid
# 10      /instagram/user/theellenshow      theellenshow
# 11       /instagram/user/fcbarcelona       fcbarcelona
# 12   /instagram/user/victoriassecret   victoriassecret
# 13              /instagram/user/9gag              9gag
# 14        /instagram/user/ronaldinho        ronaldinho
# 15         /instagram/user/iamcardib         iamcardib
# 16              /instagram/user/nasa              nasa
# 17   /instagram/user/championsleague   championsleague
# 18    /instagram/user/priyankachopra    priyankachopra
# 19  /instagram/user/jamesrodriguez10  jamesrodriguez10
# 20      /instagram/user/garethbale11      garethbale11
# 21      /instagram/user/nikefootball      nikefootball
# 22            /instagram/user/marvel            marvel
# 23     /instagram/user/marcelotwelve     marcelotwelve
# 24            /instagram/user/anitta            anitta

# %% [markdown]
# ### Cleaning data

# %%
# remove unused columns
df.drop(df.columns[[5,6]], axis=1, inplace=True)
df.head(25)
# Out:
#                         Name    followers  following grade    posts  \
# 0                    therock  145664920.0      370.0  A++    4279.0
# 1                  Leo Messi  123905769.0      228.0  A++     474.0
# 2                   3n310ta   113580705.0      993.0  A++    4430.0
# 3        National Geographic  112514923.0      131.0  A++   20489.0
# 4             Jennifer Lopez   95777045.0     1101.0  A++    2583.0
# 5                Miley Cyrus   94927303.0      780.0  A++     333.0
# 6                       nike   89453277.0       54.0  A++     733.0
# 7                 KATY PERRY   83335390.0      473.0  A++    1254.0
# 8                 Kevin Hart   76315848.0      554.0  A++    6371.0
# 9           Real Madrid C.F.   74246209.0       40.0  A++    2758.0
# 10                     Ellen   73987069.0      368.0  A++    7604.0
# 11              FC Barcelona   73020981.0       52.0  A++   11977.0
# 12         Victoria's Secret   67429383.0      573.0  A++    7761.0
# 13    9GAG: Go Fun The World   50387766.0       28.0  A++   20062.0
# 14  Ronaldo de Assis Moreira   46592552.0      316.0  A++    2365.0
# 15            MOSTHATEDCARDI   46562771.0     3096.0  A++     786.0
# 16                      NASA   44948240.0       85.0  A++    2652.0
# 17     UEFA Champions League   42805504.0      481.0  A++    9110.0
# 18     Priyanka Chopra Jonas   42635997.0      458.0  A++    2902.0
# 19           James Rodríguez   42080184.0      518.0  A++     860.0
# 20               Gareth Bale   40238795.0       64.0  A++     837.0
# 21    Nike Football (Soccer)   39127128.0      294.0  A++    1703.0
# 22      Marvel Entertainment   39013176.0      152.0  A++    3553.0
# 23        Marcelo Vieira Jr.   38964331.0     1294.0  A++    2065.0
# 24                   anitta    38851663.0     1781.0  A++    3789.0
#
#             username
# 0            therock
# 1           leomessi
# 2           neymarjr
# 3             natgeo
# 4                jlo
# 5         mileycyrus
# 6               nike
# 7          katyperry
# 8     kevinhart4real
# 9         realmadrid
# 10      theellenshow
# 11       fcbarcelona
# 12   victoriassecret
# 13              9gag
# 14        ronaldinho
# 15         iamcardib
# 16              nasa
# 17   championsleague
# 18    priyankachopra
# 19  jamesrodriguez10
# 20      garethbale11
# 21      nikefootball
# 22            marvel
# 23     marcelotwelve
# 24            anitta

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style
#%matplotlib inline

# %%
ax = sns.barplot(x="followers", y="username", data= df, palette=("BuGn_d"))
style.use('seaborn-poster')
plt.title('Accounts with more number of Followers', fontweight='bold',fontsize =26)
plt.xlabel("Followers (in millions)", fontweight='bold',fontsize =28)
plt.ylabel(" ", fontweight='bold',fontsize =28)
plt.tight_layout()
plt.savefig('subscribers.png', Transparent = True)

# %%
ax = sns.barplot(x="posts", y="username", data= df, palette=("BuGn_d"))
#sns.set_context("poster")
#style.use('seaborn-poster')
plt.title('Accounts with more number of Posts', fontweight='bold',fontsize =26)
plt.xlabel("Posts", fontweight='bold',fontsize =28)
plt.ylabel(" ", fontweight='bold',fontsize =28)
plt.tight_layout()
plt.savefig('views.png', Transparent = True)

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# ### From the above graphs, we can clearly state that "therock" has highest number of followers but not highest number of posts as we can see "natgeo" has highest number of posts.

# %% [markdown]
# ### Also, 9gag which has second highest posts, has less number of followers compared to the accounts with highest followers

# %% [markdown]
# ### So, from the above two graphs we can conclude that, an account with highest number of followers need not have highest number of posts and we can also conclude that an account with highest number of posts need not be an account with highest followers.
